# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenHungThuong/Deeplearning.AI/blob/main/Custom-models-layers-loss-functions-with-tensorflow/C1_W1_Lab_2_multi_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 991us/sample - loss: 233.6839 - y1_output_loss: 112.3742 - y2_output_loss: 119.0572 - y1_output_root_mean_squared_error: 10.6522 - y2_output_root_mean_squared_error: 10.9642 - val_loss: 38.7167 - val_y1_output_loss: 15.4242 - val_y2_output_loss: 22.4733 - val_y1_output_root_mean_squared_error: 3.9663 - val_y2_output_root_mean_squared_error: 4.7943
# Epoch 2/500
# 614/614 [==============================] - 0s 171us/sample - loss: 28.9071 - y1_output_loss: 11.8620 - y2_output_loss: 16.8636 - y1_output_root_mean_squared_error: 3.4537 - y2_output_root_mean_squared_error: 4.1206 - val_loss: 21.2415 - val_y1_output_loss: 9.4273 - val_y2_output_loss: 11.4222 - val_y1_output_root_mean_squared_error: 3.1016 - val_y2_output_root_mean_squared_error: 3.4090
# Epoch 3/500
# 614/614 [==============================] - 0s 143us/sample - loss: 28.6592 - y1_output_loss: 10.9867 - y2_output_loss: 17.7087 - y1_output_root_mean_squared_error: 3.2924 - y2_output_root_mean_squared_error: 4.2213 - val_loss: 28.8998 - val_y1_output_loss: 11.5306 - val_y2_output_loss: 17.6531 - val_y1_output_root_mean_squared_error: 3.3734 - val_y2_output_root_mean_squared_error: 4.1857
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 31.4349 - y1_output_loss: 10.6034 - y2_output_loss: 20.6576 - y1_output_root_mean_squared_error: 3.2701 - y2_output_root_mean_squared_error: 4.5543 - val_loss: 23.5631 - val_y1_output_loss: 9.6891 - val_y2_output_loss: 13.9137 - val_y1_output_root_mean_squared_error: 3.1115 - val_y2_output_root_mean_squared_error: 3.7258
# Epoch 5/500
# 614/614 [==============================] - 0s 139us/sample - loss: 25.6446 - y1_output_loss: 9.6490 - y2_output_loss: 15.7786 - y1_output_root_mean_squared_error: 3.1190 - y2_output_root_mean_squared_error: 3.9896 - val_loss: 17.6118 - val_y1_output_loss: 7.3021 - val_y2_output_loss: 10.0208 - val_y1_output_root_mean_squared_error: 2.7005 - val_y2_output_root_mean_squared_error: 3.2124
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.5897 - y1_output_loss: 8.9341 - y2_output_loss: 12.5780 - y1_output_root_mean_squared_error: 2.9985 - y2_output_root_mean_squared_error: 3.5494 - val_loss: 18.9921 - val_y1_output_loss: 6.5612 - val_y2_output_loss: 12.0545 - val_y1_output_root_mean_squared_error: 2.5653 - val_y2_output_root_mean_squared_error: 3.5230
# Epoch 7/500
# 614/614 [==============================] - 0s 140us/sample - loss: 23.9105 - y1_output_loss: 8.9809 - y2_output_loss: 14.9054 - y1_output_root_mean_squared_error: 2.9918 - y2_output_root_mean_squared_error: 3.8677 - val_loss: 18.4309 - val_y1_output_loss: 6.8889 - val_y2_output_loss: 11.2797 - val_y1_output_root_mean_squared_error: 2.6047 - val_y2_output_root_mean_squared_error: 3.4127
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 21.6014 - y1_output_loss: 8.5319 - y2_output_loss: 12.8718 - y1_output_root_mean_squared_error: 2.9341 - y2_output_root_mean_squared_error: 3.6045 - val_loss: 15.4435 - val_y1_output_loss: 6.1664 - val_y2_output_loss: 9.0518 - val_y1_output_root_mean_squared_error: 2.4706 - val_y2_output_root_mean_squared_error: 3.0561
# Epoch 9/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.1789 - y1_output_loss: 7.9864 - y2_output_loss: 12.3057 - y1_output_root_mean_squared_error: 2.8191 - y2_output_root_mean_squared_error: 3.4973 - val_loss: 35.4021 - val_y1_output_loss: 9.8161 - val_y2_output_loss: 24.7802 - val_y1_output_root_mean_squared_error: 3.1541 - val_y2_output_root_mean_squared_error: 5.0452
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.5102 - y1_output_loss: 7.8510 - y2_output_loss: 13.5089 - y1_output_root_mean_squared_error: 2.8110 - y2_output_root_mean_squared_error: 3.6890 - val_loss: 18.5959 - val_y1_output_loss: 8.2449 - val_y2_output_loss: 10.3389 - val_y1_output_root_mean_squared_error: 2.8487 - val_y2_output_root_mean_squared_error: 3.2374
# Epoch 11/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.3860 - y1_output_loss: 7.7373 - y2_output_loss: 13.6924 - y1_output_root_mean_squared_error: 2.7842 - y2_output_root_mean_squared_error: 3.6924 - val_loss: 19.6361 - val_y1_output_loss: 6.5106 - val_y2_output_loss: 12.7963 - val_y1_output_root_mean_squared_error: 2.5380 - val_y2_output_root_mean_squared_error: 3.6324
# Epoch 12/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.9215 - y1_output_loss: 7.3868 - y2_output_loss: 11.6332 - y1_output_root_mean_squared_error: 2.6964 - y2_output_root_mean_squared_error: 3.4133 - val_loss: 44.9492 - val_y1_output_loss: 11.8378 - val_y2_output_loss: 32.2421 - val_y1_output_root_mean_squared_error: 3.4651 - val_y2_output_root_mean_squared_error: 5.7396
# Epoch 13/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.9540 - y1_output_loss: 7.1807 - y2_output_loss: 10.6161 - y1_output_root_mean_squared_error: 2.6910 - y2_output_root_mean_squared_error: 3.2730 - val_loss: 14.1431 - val_y1_output_loss: 5.6305 - val_y2_output_loss: 8.3479 - val_y1_output_root_mean_squared_error: 2.3540 - val_y2_output_root_mean_squared_error: 2.9328
# Epoch 14/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.7215 - y1_output_loss: 6.2886 - y2_output_loss: 9.5269 - y1_output_root_mean_squared_error: 2.5027 - y2_output_root_mean_squared_error: 3.0753 - val_loss: 15.1956 - val_y1_output_loss: 6.9741 - val_y2_output_loss: 8.5379 - val_y1_output_root_mean_squared_error: 2.5556 - val_y2_output_root_mean_squared_error: 2.9435
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 17.4099 - y1_output_loss: 6.5990 - y2_output_loss: 10.8121 - y1_output_root_mean_squared_error: 2.5687 - y2_output_root_mean_squared_error: 3.2881 - val_loss: 17.2005 - val_y1_output_loss: 6.1713 - val_y2_output_loss: 10.8399 - val_y1_output_root_mean_squared_error: 2.4540 - val_y2_output_root_mean_squared_error: 3.3434
# Epoch 16/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.3299 - y1_output_loss: 5.7875 - y2_output_loss: 9.4194 - y1_output_root_mean_squared_error: 2.4131 - y2_output_root_mean_squared_error: 3.0833 - val_loss: 12.0106 - val_y1_output_loss: 5.1525 - val_y2_output_loss: 6.9797 - val_y1_output_root_mean_squared_error: 2.2025 - val_y2_output_root_mean_squared_error: 2.6758
# Epoch 17/500
# 614/614 [==============================] - 0s 146us/sample - loss: 16.1389 - y1_output_loss: 6.1481 - y2_output_loss: 10.2246 - y1_output_root_mean_squared_error: 2.4556 - y2_output_root_mean_squared_error: 3.1795 - val_loss: 35.5836 - val_y1_output_loss: 9.2556 - val_y2_output_loss: 25.7081 - val_y1_output_root_mean_squared_error: 3.0556 - val_y2_output_root_mean_squared_error: 5.1232
# Epoch 18/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.3306 - y1_output_loss: 5.6852 - y2_output_loss: 9.6871 - y1_output_root_mean_squared_error: 2.3671 - y2_output_root_mean_squared_error: 3.1189 - val_loss: 14.9815 - val_y1_output_loss: 6.8578 - val_y2_output_loss: 8.0293 - val_y1_output_root_mean_squared_error: 2.5943 - val_y2_output_root_mean_squared_error: 2.8725
# Epoch 19/500
# 614/614 [==============================] - 0s 148us/sample - loss: 14.2560 - y1_output_loss: 5.1857 - y2_output_loss: 9.1287 - y1_output_root_mean_squared_error: 2.2798 - y2_output_root_mean_squared_error: 3.0098 - val_loss: 50.0492 - val_y1_output_loss: 16.5174 - val_y2_output_loss: 33.6157 - val_y1_output_root_mean_squared_error: 4.0444 - val_y2_output_root_mean_squared_error: 5.8045
# Epoch 20/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.9599 - y1_output_loss: 5.2156 - y2_output_loss: 8.7057 - y1_output_root_mean_squared_error: 2.2866 - y2_output_root_mean_squared_error: 2.9549 - val_loss: 11.9605 - val_y1_output_loss: 4.9287 - val_y2_output_loss: 6.8926 - val_y1_output_root_mean_squared_error: 2.1950 - val_y2_output_root_mean_squared_error: 2.6726
# Epoch 21/500
# 614/614 [==============================] - 0s 146us/sample - loss: 11.6597 - y1_output_loss: 4.3102 - y2_output_loss: 7.3358 - y1_output_root_mean_squared_error: 2.0791 - y2_output_root_mean_squared_error: 2.7087 - val_loss: 15.7585 - val_y1_output_loss: 5.6139 - val_y2_output_loss: 10.1460 - val_y1_output_root_mean_squared_error: 2.3488 - val_y2_output_root_mean_squared_error: 3.2003
# Epoch 22/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.4314 - y1_output_loss: 4.5897 - y2_output_loss: 8.7349 - y1_output_root_mean_squared_error: 2.1495 - y2_output_root_mean_squared_error: 2.9684 - val_loss: 8.7723 - val_y1_output_loss: 4.0125 - val_y2_output_loss: 4.8661 - val_y1_output_root_mean_squared_error: 1.9396 - val_y2_output_root_mean_squared_error: 2.2383
# Epoch 23/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.8712 - y1_output_loss: 4.2382 - y2_output_loss: 7.6113 - y1_output_root_mean_squared_error: 2.0610 - y2_output_root_mean_squared_error: 2.7610 - val_loss: 8.9573 - val_y1_output_loss: 3.8855 - val_y2_output_loss: 5.0506 - val_y1_output_root_mean_squared_error: 1.9306 - val_y2_output_root_mean_squared_error: 2.2870
# Epoch 24/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.5482 - y1_output_loss: 4.0917 - y2_output_loss: 6.4512 - y1_output_root_mean_squared_error: 2.0166 - y2_output_root_mean_squared_error: 2.5459 - val_loss: 9.9305 - val_y1_output_loss: 4.2096 - val_y2_output_loss: 5.7681 - val_y1_output_root_mean_squared_error: 2.0176 - val_y2_output_root_mean_squared_error: 2.4207
# Epoch 25/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.3155 - y1_output_loss: 3.8483 - y2_output_loss: 7.4314 - y1_output_root_mean_squared_error: 1.9645 - y2_output_root_mean_squared_error: 2.7306 - val_loss: 14.0546 - val_y1_output_loss: 4.1698 - val_y2_output_loss: 9.7684 - val_y1_output_root_mean_squared_error: 2.0139 - val_y2_output_root_mean_squared_error: 3.1621
# Epoch 26/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.9399 - y1_output_loss: 3.7831 - y2_output_loss: 7.0735 - y1_output_root_mean_squared_error: 1.9526 - y2_output_root_mean_squared_error: 2.6697 - val_loss: 8.4787 - val_y1_output_loss: 3.3556 - val_y2_output_loss: 5.1035 - val_y1_output_root_mean_squared_error: 1.7862 - val_y2_output_root_mean_squared_error: 2.2996
# Epoch 27/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.0858 - y1_output_loss: 3.6978 - y2_output_loss: 7.3580 - y1_output_root_mean_squared_error: 1.9297 - y2_output_root_mean_squared_error: 2.7133 - val_loss: 8.4582 - val_y1_output_loss: 2.9434 - val_y2_output_loss: 5.5706 - val_y1_output_root_mean_squared_error: 1.6585 - val_y2_output_root_mean_squared_error: 2.3891
# Epoch 28/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.6614 - y1_output_loss: 3.4635 - y2_output_loss: 7.1305 - y1_output_root_mean_squared_error: 1.8672 - y2_output_root_mean_squared_error: 2.6786 - val_loss: 7.1563 - val_y1_output_loss: 3.6311 - val_y2_output_loss: 3.8748 - val_y1_output_root_mean_squared_error: 1.7956 - val_y2_output_root_mean_squared_error: 1.9829
# Epoch 29/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.9343 - y1_output_loss: 3.1005 - y2_output_loss: 6.0291 - y1_output_root_mean_squared_error: 1.7389 - y2_output_root_mean_squared_error: 2.4311 - val_loss: 29.5434 - val_y1_output_loss: 6.8242 - val_y2_output_loss: 22.4223 - val_y1_output_root_mean_squared_error: 2.6060 - val_y2_output_root_mean_squared_error: 4.7699
# Epoch 30/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.5373 - y1_output_loss: 3.2431 - y2_output_loss: 6.3374 - y1_output_root_mean_squared_error: 1.8029 - y2_output_root_mean_squared_error: 2.5073 - val_loss: 15.0285 - val_y1_output_loss: 5.6830 - val_y2_output_loss: 9.4439 - val_y1_output_root_mean_squared_error: 2.3478 - val_y2_output_root_mean_squared_error: 3.0848
# Epoch 31/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.7362 - y1_output_loss: 3.1968 - y2_output_loss: 6.5333 - y1_output_root_mean_squared_error: 1.7819 - y2_output_root_mean_squared_error: 2.5615 - val_loss: 10.7233 - val_y1_output_loss: 3.0179 - val_y2_output_loss: 7.6688 - val_y1_output_root_mean_squared_error: 1.6918 - val_y2_output_root_mean_squared_error: 2.8038
# Epoch 32/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.5206 - y1_output_loss: 2.8686 - y2_output_loss: 6.6302 - y1_output_root_mean_squared_error: 1.6913 - y2_output_root_mean_squared_error: 2.5807 - val_loss: 6.7970 - val_y1_output_loss: 3.1662 - val_y2_output_loss: 3.7950 - val_y1_output_root_mean_squared_error: 1.7100 - val_y2_output_root_mean_squared_error: 1.9680
# Epoch 33/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.6973 - y1_output_loss: 2.5869 - y2_output_loss: 5.0871 - y1_output_root_mean_squared_error: 1.6112 - y2_output_root_mean_squared_error: 2.2586 - val_loss: 15.0582 - val_y1_output_loss: 6.7077 - val_y2_output_loss: 8.4271 - val_y1_output_root_mean_squared_error: 2.5461 - val_y2_output_root_mean_squared_error: 2.9284
# Epoch 34/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.0928 - y1_output_loss: 2.8620 - y2_output_loss: 6.1870 - y1_output_root_mean_squared_error: 1.6957 - y2_output_root_mean_squared_error: 2.4934 - val_loss: 6.2064 - val_y1_output_loss: 2.8654 - val_y2_output_loss: 3.5148 - val_y1_output_root_mean_squared_error: 1.6270 - val_y2_output_root_mean_squared_error: 1.8866
# Epoch 35/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.8022 - y1_output_loss: 2.5557 - y2_output_loss: 5.2350 - y1_output_root_mean_squared_error: 1.5946 - y2_output_root_mean_squared_error: 2.2933 - val_loss: 13.1132 - val_y1_output_loss: 4.0255 - val_y2_output_loss: 8.8933 - val_y1_output_root_mean_squared_error: 1.9944 - val_y2_output_root_mean_squared_error: 3.0225
# Epoch 36/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.3197 - y1_output_loss: 2.4122 - y2_output_loss: 4.8459 - y1_output_root_mean_squared_error: 1.5599 - y2_output_root_mean_squared_error: 2.2105 - val_loss: 7.4522 - val_y1_output_loss: 2.2489 - val_y2_output_loss: 5.2700 - val_y1_output_root_mean_squared_error: 1.4396 - val_y2_output_root_mean_squared_error: 2.3194
# Epoch 37/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9748 - y1_output_loss: 2.2038 - y2_output_loss: 4.7675 - y1_output_root_mean_squared_error: 1.4797 - y2_output_root_mean_squared_error: 2.1875 - val_loss: 6.2384 - val_y1_output_loss: 2.5936 - val_y2_output_loss: 3.6931 - val_y1_output_root_mean_squared_error: 1.5644 - val_y2_output_root_mean_squared_error: 1.9470
# Epoch 38/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.6697 - y1_output_loss: 2.8212 - y2_output_loss: 6.7606 - y1_output_root_mean_squared_error: 1.6875 - y2_output_root_mean_squared_error: 2.6119 - val_loss: 9.7071 - val_y1_output_loss: 3.6375 - val_y2_output_loss: 6.2318 - val_y1_output_root_mean_squared_error: 1.8459 - val_y2_output_root_mean_squared_error: 2.5099
# Epoch 39/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.2022 - y1_output_loss: 2.3428 - y2_output_loss: 5.7950 - y1_output_root_mean_squared_error: 1.5339 - y2_output_root_mean_squared_error: 2.4185 - val_loss: 6.3239 - val_y1_output_loss: 2.7022 - val_y2_output_loss: 3.6225 - val_y1_output_root_mean_squared_error: 1.6032 - val_y2_output_root_mean_squared_error: 1.9374
# Epoch 40/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.2307 - y1_output_loss: 2.2909 - y2_output_loss: 4.9395 - y1_output_root_mean_squared_error: 1.5087 - y2_output_root_mean_squared_error: 2.2258 - val_loss: 17.3834 - val_y1_output_loss: 4.2574 - val_y2_output_loss: 12.9609 - val_y1_output_root_mean_squared_error: 2.0520 - val_y2_output_root_mean_squared_error: 3.6294
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.8729 - y1_output_loss: 2.7425 - y2_output_loss: 7.1848 - y1_output_root_mean_squared_error: 1.6460 - y2_output_root_mean_squared_error: 2.6765 - val_loss: 8.9619 - val_y1_output_loss: 2.3580 - val_y2_output_loss: 6.6762 - val_y1_output_root_mean_squared_error: 1.4749 - val_y2_output_root_mean_squared_error: 2.6051
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.5522 - y1_output_loss: 2.8645 - y2_output_loss: 6.6905 - y1_output_root_mean_squared_error: 1.6908 - y2_output_root_mean_squared_error: 2.5872 - val_loss: 10.9455 - val_y1_output_loss: 3.0616 - val_y2_output_loss: 7.8151 - val_y1_output_root_mean_squared_error: 1.7178 - val_y2_output_root_mean_squared_error: 2.8275
# Epoch 43/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.3984 - y1_output_loss: 2.0674 - y2_output_loss: 5.5158 - y1_output_root_mean_squared_error: 1.4410 - y2_output_root_mean_squared_error: 2.3069 - val_loss: 18.9074 - val_y1_output_loss: 5.0257 - val_y2_output_loss: 13.8698 - val_y1_output_root_mean_squared_error: 2.2210 - val_y2_output_root_mean_squared_error: 3.7383
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.5505 - y1_output_loss: 2.9319 - y2_output_loss: 6.7707 - y1_output_root_mean_squared_error: 1.7023 - y2_output_root_mean_squared_error: 2.5793 - val_loss: 33.4940 - val_y1_output_loss: 10.1861 - val_y2_output_loss: 22.6138 - val_y1_output_root_mean_squared_error: 3.2185 - val_y2_output_root_mean_squared_error: 4.8099
# Epoch 45/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.2981 - y1_output_loss: 2.5659 - y2_output_loss: 5.6662 - y1_output_root_mean_squared_error: 1.6078 - y2_output_root_mean_squared_error: 2.3902 - val_loss: 6.3871 - val_y1_output_loss: 2.2854 - val_y2_output_loss: 4.2484 - val_y1_output_root_mean_squared_error: 1.4416 - val_y2_output_root_mean_squared_error: 2.0758
# Epoch 46/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.5215 - y1_output_loss: 2.3615 - y2_output_loss: 5.1405 - y1_output_root_mean_squared_error: 1.5316 - y2_output_root_mean_squared_error: 2.2751 - val_loss: 12.6702 - val_y1_output_loss: 3.1646 - val_y2_output_loss: 9.3827 - val_y1_output_root_mean_squared_error: 1.7630 - val_y2_output_root_mean_squared_error: 3.0922
# Epoch 47/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.0543 - y1_output_loss: 2.4591 - y2_output_loss: 5.5378 - y1_output_root_mean_squared_error: 1.5757 - y2_output_root_mean_squared_error: 2.3604 - val_loss: 5.2156 - val_y1_output_loss: 1.9504 - val_y2_output_loss: 3.3243 - val_y1_output_root_mean_squared_error: 1.3495 - val_y2_output_root_mean_squared_error: 1.8424
# Epoch 48/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.6878 - y1_output_loss: 2.1161 - y2_output_loss: 5.5214 - y1_output_root_mean_squared_error: 1.4568 - y2_output_root_mean_squared_error: 2.3591 - val_loss: 6.4409 - val_y1_output_loss: 2.6660 - val_y2_output_loss: 3.7304 - val_y1_output_root_mean_squared_error: 1.6089 - val_y2_output_root_mean_squared_error: 1.9627
# Epoch 49/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.8167 - y1_output_loss: 2.2334 - y2_output_loss: 5.5652 - y1_output_root_mean_squared_error: 1.4841 - y2_output_root_mean_squared_error: 2.3694 - val_loss: 10.4884 - val_y1_output_loss: 3.2642 - val_y2_output_loss: 7.1855 - val_y1_output_root_mean_squared_error: 1.7952 - val_y2_output_root_mean_squared_error: 2.6955
# Epoch 50/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.3411 - y1_output_loss: 1.8797 - y2_output_loss: 4.4304 - y1_output_root_mean_squared_error: 1.3691 - y2_output_root_mean_squared_error: 2.1135 - val_loss: 6.9878 - val_y1_output_loss: 3.0755 - val_y2_output_loss: 3.8743 - val_y1_output_root_mean_squared_error: 1.7446 - val_y2_output_root_mean_squared_error: 1.9860
# Epoch 51/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.9710 - y1_output_loss: 1.9362 - y2_output_loss: 4.9785 - y1_output_root_mean_squared_error: 1.3971 - y2_output_root_mean_squared_error: 2.2404 - val_loss: 5.7260 - val_y1_output_loss: 2.0486 - val_y2_output_loss: 3.6879 - val_y1_output_root_mean_squared_error: 1.3939 - val_y2_output_root_mean_squared_error: 1.9450
# Epoch 52/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.3975 - y1_output_loss: 1.8039 - y2_output_loss: 4.5992 - y1_output_root_mean_squared_error: 1.3340 - y2_output_root_mean_squared_error: 2.1489 - val_loss: 7.3171 - val_y1_output_loss: 2.1556 - val_y2_output_loss: 5.0919 - val_y1_output_root_mean_squared_error: 1.4567 - val_y2_output_root_mean_squared_error: 2.2793
# Epoch 53/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.9720 - y1_output_loss: 1.9501 - y2_output_loss: 4.0249 - y1_output_root_mean_squared_error: 1.3919 - y2_output_root_mean_squared_error: 2.0087 - val_loss: 14.3689 - val_y1_output_loss: 3.7320 - val_y2_output_loss: 10.6017 - val_y1_output_root_mean_squared_error: 1.9046 - val_y2_output_root_mean_squared_error: 3.2774
# Epoch 54/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.5073 - y1_output_loss: 1.9763 - y2_output_loss: 4.5244 - y1_output_root_mean_squared_error: 1.4079 - y2_output_root_mean_squared_error: 2.1272 - val_loss: 15.3479 - val_y1_output_loss: 4.5011 - val_y2_output_loss: 10.6243 - val_y1_output_root_mean_squared_error: 2.1295 - val_y2_output_root_mean_squared_error: 3.2883
# Epoch 55/500
# 614/614 [==============================] - 0s 152us/sample - loss: 7.6949 - y1_output_loss: 2.1445 - y2_output_loss: 5.5269 - y1_output_root_mean_squared_error: 1.4592 - y2_output_root_mean_squared_error: 2.3592 - val_loss: 18.4053 - val_y1_output_loss: 6.1655 - val_y2_output_loss: 11.9553 - val_y1_output_root_mean_squared_error: 2.5091 - val_y2_output_root_mean_squared_error: 3.4799
# Epoch 56/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.0796 - y1_output_loss: 1.8347 - y2_output_loss: 5.2450 - y1_output_root_mean_squared_error: 1.3590 - y2_output_root_mean_squared_error: 2.2875 - val_loss: 6.9837 - val_y1_output_loss: 2.1080 - val_y2_output_loss: 4.8945 - val_y1_output_root_mean_squared_error: 1.4352 - val_y2_output_root_mean_squared_error: 2.2190
# Epoch 57/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.4543 - y1_output_loss: 2.2622 - y2_output_loss: 6.1145 - y1_output_root_mean_squared_error: 1.5102 - y2_output_root_mean_squared_error: 2.4846 - val_loss: 4.8331 - val_y1_output_loss: 1.4721 - val_y2_output_loss: 3.4095 - val_y1_output_root_mean_squared_error: 1.1747 - val_y2_output_root_mean_squared_error: 1.8583
# Epoch 58/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.5034 - y1_output_loss: 1.6984 - y2_output_loss: 4.8197 - y1_output_root_mean_squared_error: 1.2943 - y2_output_root_mean_squared_error: 2.1973 - val_loss: 13.9545 - val_y1_output_loss: 4.3326 - val_y2_output_loss: 9.4035 - val_y1_output_root_mean_squared_error: 2.0856 - val_y2_output_root_mean_squared_error: 3.0991
# Epoch 59/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.3361 - y1_output_loss: 1.8753 - y2_output_loss: 4.4470 - y1_output_root_mean_squared_error: 1.3658 - y2_output_root_mean_squared_error: 2.1144 - val_loss: 6.7648 - val_y1_output_loss: 2.1737 - val_y2_output_loss: 4.5353 - val_y1_output_root_mean_squared_error: 1.4477 - val_y2_output_root_mean_squared_error: 2.1608
# Epoch 60/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.5623 - y1_output_loss: 1.6164 - y2_output_loss: 4.8844 - y1_output_root_mean_squared_error: 1.2772 - y2_output_root_mean_squared_error: 2.2206 - val_loss: 4.2552 - val_y1_output_loss: 1.9002 - val_y2_output_loss: 2.3624 - val_y1_output_root_mean_squared_error: 1.3606 - val_y2_output_root_mean_squared_error: 1.5505
# Epoch 61/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8437 - y1_output_loss: 1.2714 - y2_output_loss: 3.5750 - y1_output_root_mean_squared_error: 1.1248 - y2_output_root_mean_squared_error: 1.8917 - val_loss: 6.9898 - val_y1_output_loss: 2.2926 - val_y2_output_loss: 4.6666 - val_y1_output_root_mean_squared_error: 1.5178 - val_y2_output_root_mean_squared_error: 2.1648
# Epoch 62/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.3797 - y1_output_loss: 1.4335 - y2_output_loss: 4.0656 - y1_output_root_mean_squared_error: 1.1905 - y2_output_root_mean_squared_error: 1.9906 - val_loss: 21.2870 - val_y1_output_loss: 3.7329 - val_y2_output_loss: 17.3990 - val_y1_output_root_mean_squared_error: 1.9292 - val_y2_output_root_mean_squared_error: 4.1911
# Epoch 63/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.2241 - y1_output_loss: 1.3062 - y2_output_loss: 3.8821 - y1_output_root_mean_squared_error: 1.1434 - y2_output_root_mean_squared_error: 1.9791 - val_loss: 5.6477 - val_y1_output_loss: 1.4421 - val_y2_output_loss: 4.2108 - val_y1_output_root_mean_squared_error: 1.1767 - val_y2_output_root_mean_squared_error: 2.0647
# Epoch 64/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6923 - y1_output_loss: 1.2452 - y2_output_loss: 3.4691 - y1_output_root_mean_squared_error: 1.1188 - y2_output_root_mean_squared_error: 1.8548 - val_loss: 5.8392 - val_y1_output_loss: 1.6409 - val_y2_output_loss: 4.2358 - val_y1_output_root_mean_squared_error: 1.2701 - val_y2_output_root_mean_squared_error: 2.0557
# Epoch 65/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.9633 - y1_output_loss: 0.9936 - y2_output_loss: 2.9377 - y1_output_root_mean_squared_error: 1.0006 - y2_output_root_mean_squared_error: 1.7211 - val_loss: 5.5979 - val_y1_output_loss: 1.5919 - val_y2_output_loss: 4.0462 - val_y1_output_root_mean_squared_error: 1.2436 - val_y2_output_root_mean_squared_error: 2.0128
# Epoch 66/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.0503 - y1_output_loss: 1.8036 - y2_output_loss: 4.2479 - y1_output_root_mean_squared_error: 1.3437 - y2_output_root_mean_squared_error: 2.0603 - val_loss: 3.7461 - val_y1_output_loss: 1.3167 - val_y2_output_loss: 2.4992 - val_y1_output_root_mean_squared_error: 1.1155 - val_y2_output_root_mean_squared_error: 1.5817
# Epoch 67/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.8105 - y1_output_loss: 1.0950 - y2_output_loss: 3.7402 - y1_output_root_mean_squared_error: 1.0444 - y2_output_root_mean_squared_error: 1.9287 - val_loss: 3.7644 - val_y1_output_loss: 1.1547 - val_y2_output_loss: 2.6773 - val_y1_output_root_mean_squared_error: 1.0606 - val_y2_output_root_mean_squared_error: 1.6246
# Epoch 68/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.3574 - y1_output_loss: 1.0458 - y2_output_loss: 3.2781 - y1_output_root_mean_squared_error: 1.0268 - y2_output_root_mean_squared_error: 1.8174 - val_loss: 6.9503 - val_y1_output_loss: 1.7365 - val_y2_output_loss: 5.2438 - val_y1_output_root_mean_squared_error: 1.3192 - val_y2_output_root_mean_squared_error: 2.2826
# Epoch 69/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.4428 - y1_output_loss: 1.0698 - y2_output_loss: 3.3572 - y1_output_root_mean_squared_error: 1.0380 - y2_output_root_mean_squared_error: 1.8345 - val_loss: 4.0534 - val_y1_output_loss: 1.5506 - val_y2_output_loss: 2.5955 - val_y1_output_root_mean_squared_error: 1.2276 - val_y2_output_root_mean_squared_error: 1.5957
# Epoch 70/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.5042 - y1_output_loss: 1.1087 - y2_output_loss: 3.4619 - y1_output_root_mean_squared_error: 1.0487 - y2_output_root_mean_squared_error: 1.8451 - val_loss: 28.1733 - val_y1_output_loss: 8.1310 - val_y2_output_loss: 19.4234 - val_y1_output_root_mean_squared_error: 2.8863 - val_y2_output_root_mean_squared_error: 4.4545
# Epoch 71/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.5152 - y1_output_loss: 1.7896 - y2_output_loss: 4.7783 - y1_output_root_mean_squared_error: 1.3425 - y2_output_root_mean_squared_error: 2.1709 - val_loss: 22.3728 - val_y1_output_loss: 4.3785 - val_y2_output_loss: 17.8970 - val_y1_output_root_mean_squared_error: 2.0998 - val_y2_output_root_mean_squared_error: 4.2383
# Epoch 72/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.4899 - y1_output_loss: 1.4515 - y2_output_loss: 4.0177 - y1_output_root_mean_squared_error: 1.2013 - y2_output_root_mean_squared_error: 2.0117 - val_loss: 6.9599 - val_y1_output_loss: 2.2413 - val_y2_output_loss: 4.7547 - val_y1_output_root_mean_squared_error: 1.5032 - val_y2_output_root_mean_squared_error: 2.1680
# Epoch 73/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.7869 - y1_output_loss: 1.0990 - y2_output_loss: 3.7500 - y1_output_root_mean_squared_error: 1.0448 - y2_output_root_mean_squared_error: 1.9223 - val_loss: 11.4657 - val_y1_output_loss: 4.8563 - val_y2_output_loss: 6.6001 - val_y1_output_root_mean_squared_error: 2.2029 - val_y2_output_root_mean_squared_error: 2.5715
# Epoch 74/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.8402 - y1_output_loss: 0.8475 - y2_output_loss: 2.9796 - y1_output_root_mean_squared_error: 0.9223 - y2_output_root_mean_squared_error: 1.7290 - val_loss: 3.0188 - val_y1_output_loss: 1.0402 - val_y2_output_loss: 2.0457 - val_y1_output_root_mean_squared_error: 0.9974 - val_y2_output_root_mean_squared_error: 1.4227
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4773 - y1_output_loss: 0.7417 - y2_output_loss: 2.7754 - y1_output_root_mean_squared_error: 0.8489 - y2_output_root_mean_squared_error: 1.6603 - val_loss: 7.2573 - val_y1_output_loss: 1.8522 - val_y2_output_loss: 5.4239 - val_y1_output_root_mean_squared_error: 1.3578 - val_y2_output_root_mean_squared_error: 2.3267
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.2246 - y1_output_loss: 0.6846 - y2_output_loss: 2.5754 - y1_output_root_mean_squared_error: 0.8277 - y2_output_root_mean_squared_error: 1.5936 - val_loss: 5.1060 - val_y1_output_loss: 1.9132 - val_y2_output_loss: 3.1810 - val_y1_output_root_mean_squared_error: 1.3961 - val_y2_output_root_mean_squared_error: 1.7768
# Epoch 77/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.2620 - y1_output_loss: 0.9582 - y2_output_loss: 3.3998 - y1_output_root_mean_squared_error: 0.9830 - y2_output_root_mean_squared_error: 1.8154 - val_loss: 15.4290 - val_y1_output_loss: 2.4374 - val_y2_output_loss: 12.8666 - val_y1_output_root_mean_squared_error: 1.5625 - val_y2_output_root_mean_squared_error: 3.6038
# Epoch 78/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.7218 - y1_output_loss: 0.8890 - y2_output_loss: 3.8791 - y1_output_root_mean_squared_error: 0.9411 - y2_output_root_mean_squared_error: 1.9586 - val_loss: 6.6053 - val_y1_output_loss: 1.2246 - val_y2_output_loss: 5.3783 - val_y1_output_root_mean_squared_error: 1.1067 - val_y2_output_root_mean_squared_error: 2.3196
# Epoch 79/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1274 - y1_output_loss: 0.6911 - y2_output_loss: 2.4588 - y1_output_root_mean_squared_error: 0.8265 - y2_output_root_mean_squared_error: 1.5634 - val_loss: 6.8251 - val_y1_output_loss: 1.6814 - val_y2_output_loss: 5.2327 - val_y1_output_root_mean_squared_error: 1.2771 - val_y2_output_root_mean_squared_error: 2.2790
# Epoch 80/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1044 - y1_output_loss: 0.6662 - y2_output_loss: 2.4277 - y1_output_root_mean_squared_error: 0.8154 - y2_output_root_mean_squared_error: 1.5619 - val_loss: 3.0102 - val_y1_output_loss: 0.8752 - val_y2_output_loss: 2.1731 - val_y1_output_root_mean_squared_error: 0.9382 - val_y2_output_root_mean_squared_error: 1.4595
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6553 - y1_output_loss: 0.7998 - y2_output_loss: 2.8644 - y1_output_root_mean_squared_error: 0.8933 - y2_output_root_mean_squared_error: 1.6904 - val_loss: 10.7609 - val_y1_output_loss: 3.3836 - val_y2_output_loss: 7.2610 - val_y1_output_root_mean_squared_error: 1.8506 - val_y2_output_root_mean_squared_error: 2.7086
# Epoch 82/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6682 - y1_output_loss: 0.7910 - y2_output_loss: 2.8541 - y1_output_root_mean_squared_error: 0.8888 - y2_output_root_mean_squared_error: 1.6965 - val_loss: 3.4645 - val_y1_output_loss: 0.8562 - val_y2_output_loss: 2.6708 - val_y1_output_root_mean_squared_error: 0.9114 - val_y2_output_root_mean_squared_error: 1.6229
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5338 - y1_output_loss: 0.7013 - y2_output_loss: 2.8343 - y1_output_root_mean_squared_error: 0.8382 - y2_output_root_mean_squared_error: 1.6826 - val_loss: 8.0634 - val_y1_output_loss: 1.7579 - val_y2_output_loss: 6.3894 - val_y1_output_root_mean_squared_error: 1.3207 - val_y2_output_root_mean_squared_error: 2.5138
# Epoch 84/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.3170 - y1_output_loss: 1.0487 - y2_output_loss: 3.2456 - y1_output_root_mean_squared_error: 1.0274 - y2_output_root_mean_squared_error: 1.8059 - val_loss: 3.6817 - val_y1_output_loss: 1.4149 - val_y2_output_loss: 2.3010 - val_y1_output_root_mean_squared_error: 1.1822 - val_y2_output_root_mean_squared_error: 1.5114
# Epoch 85/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.9408 - y1_output_loss: 0.6528 - y2_output_loss: 2.3451 - y1_output_root_mean_squared_error: 0.8089 - y2_output_root_mean_squared_error: 1.5121 - val_loss: 22.3761 - val_y1_output_loss: 2.7821 - val_y2_output_loss: 19.3569 - val_y1_output_root_mean_squared_error: 1.6781 - val_y2_output_root_mean_squared_error: 4.4227
# Epoch 86/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.7746 - y1_output_loss: 1.1888 - y2_output_loss: 3.5580 - y1_output_root_mean_squared_error: 1.0944 - y2_output_root_mean_squared_error: 1.8913 - val_loss: 4.8537 - val_y1_output_loss: 1.5953 - val_y2_output_loss: 3.2880 - val_y1_output_root_mean_squared_error: 1.2741 - val_y2_output_root_mean_squared_error: 1.7973
# Epoch 87/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.2329 - y1_output_loss: 0.9719 - y2_output_loss: 3.2228 - y1_output_root_mean_squared_error: 0.9904 - y2_output_root_mean_squared_error: 1.8033 - val_loss: 2.5984 - val_y1_output_loss: 0.7850 - val_y2_output_loss: 1.8760 - val_y1_output_root_mean_squared_error: 0.8662 - val_y2_output_root_mean_squared_error: 1.3595
# Epoch 88/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.7513 - y1_output_loss: 0.5822 - y2_output_loss: 2.1509 - y1_output_root_mean_squared_error: 0.7662 - y2_output_root_mean_squared_error: 1.4711 - val_loss: 2.2349 - val_y1_output_loss: 0.6013 - val_y2_output_loss: 1.6875 - val_y1_output_root_mean_squared_error: 0.7634 - val_y2_output_root_mean_squared_error: 1.2853
# Epoch 89/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.7954 - y1_output_loss: 0.8554 - y2_output_loss: 2.9190 - y1_output_root_mean_squared_error: 0.9287 - y2_output_root_mean_squared_error: 1.7126 - val_loss: 5.9823 - val_y1_output_loss: 1.3127 - val_y2_output_loss: 4.6571 - val_y1_output_root_mean_squared_error: 1.1416 - val_y2_output_root_mean_squared_error: 2.1631
# Epoch 90/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7787 - y1_output_loss: 0.5955 - y2_output_loss: 2.1707 - y1_output_root_mean_squared_error: 0.7738 - y2_output_root_mean_squared_error: 1.4765 - val_loss: 2.2876 - val_y1_output_loss: 0.6397 - val_y2_output_loss: 1.7090 - val_y1_output_root_mean_squared_error: 0.7924 - val_y2_output_root_mean_squared_error: 1.2883
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6585 - y1_output_loss: 0.7730 - y2_output_loss: 2.8712 - y1_output_root_mean_squared_error: 0.8766 - y2_output_root_mean_squared_error: 1.7000 - val_loss: 2.6599 - val_y1_output_loss: 1.1708 - val_y2_output_loss: 1.5196 - val_y1_output_root_mean_squared_error: 1.0701 - val_y2_output_root_mean_squared_error: 1.2308
# Epoch 92/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.4302 - y1_output_loss: 0.5108 - y2_output_loss: 1.9041 - y1_output_root_mean_squared_error: 0.7131 - y2_output_root_mean_squared_error: 1.3863 - val_loss: 2.2226 - val_y1_output_loss: 0.6267 - val_y2_output_loss: 1.6796 - val_y1_output_root_mean_squared_error: 0.7737 - val_y2_output_root_mean_squared_error: 1.2743
# Epoch 93/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.5898 - y1_output_loss: 0.7521 - y2_output_loss: 2.8336 - y1_output_root_mean_squared_error: 0.8674 - y2_output_root_mean_squared_error: 1.6845 - val_loss: 3.6048 - val_y1_output_loss: 1.1969 - val_y2_output_loss: 2.4133 - val_y1_output_root_mean_squared_error: 1.0966 - val_y2_output_root_mean_squared_error: 1.5499
# Epoch 94/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.1029 - y1_output_loss: 0.5923 - y2_output_loss: 2.4889 - y1_output_root_mean_squared_error: 0.7717 - y2_output_root_mean_squared_error: 1.5834 - val_loss: 2.9042 - val_y1_output_loss: 1.0107 - val_y2_output_loss: 1.9559 - val_y1_output_root_mean_squared_error: 1.0064 - val_y2_output_root_mean_squared_error: 1.3753
# Epoch 95/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.5130 - y1_output_loss: 0.5647 - y2_output_loss: 1.9267 - y1_output_root_mean_squared_error: 0.7544 - y2_output_root_mean_squared_error: 1.3942 - val_loss: 2.3064 - val_y1_output_loss: 0.6320 - val_y2_output_loss: 1.7319 - val_y1_output_root_mean_squared_error: 0.7919 - val_y2_output_root_mean_squared_error: 1.2959
# Epoch 96/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.8024 - y1_output_loss: 0.5559 - y2_output_loss: 2.2267 - y1_output_root_mean_squared_error: 0.7472 - y2_output_root_mean_squared_error: 1.4980 - val_loss: 2.4496 - val_y1_output_loss: 1.0338 - val_y2_output_loss: 1.4553 - val_y1_output_root_mean_squared_error: 1.0201 - val_y2_output_root_mean_squared_error: 1.1870
# Epoch 97/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.5848 - y1_output_loss: 1.2054 - y2_output_loss: 3.3736 - y1_output_root_mean_squared_error: 1.1018 - y2_output_root_mean_squared_error: 1.8360 - val_loss: 2.6225 - val_y1_output_loss: 0.7417 - val_y2_output_loss: 1.9545 - val_y1_output_root_mean_squared_error: 0.8448 - val_y2_output_root_mean_squared_error: 1.3816
# Epoch 98/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0179 - y1_output_loss: 0.6506 - y2_output_loss: 2.3601 - y1_output_root_mean_squared_error: 0.8070 - y2_output_root_mean_squared_error: 1.5384 - val_loss: 3.4483 - val_y1_output_loss: 0.9538 - val_y2_output_loss: 2.5513 - val_y1_output_root_mean_squared_error: 0.9614 - val_y2_output_root_mean_squared_error: 1.5887
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.5591 - y1_output_loss: 2.0915 - y2_output_loss: 5.4001 - y1_output_root_mean_squared_error: 1.4526 - y2_output_root_mean_squared_error: 2.3343 - val_loss: 2.7618 - val_y1_output_loss: 0.9756 - val_y2_output_loss: 1.7847 - val_y1_output_root_mean_squared_error: 0.9904 - val_y2_output_root_mean_squared_error: 1.3345
# Epoch 100/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5913 - y1_output_loss: 0.5534 - y2_output_loss: 2.0271 - y1_output_root_mean_squared_error: 0.7419 - y2_output_root_mean_squared_error: 1.4286 - val_loss: 2.6674 - val_y1_output_loss: 0.7817 - val_y2_output_loss: 1.9389 - val_y1_output_root_mean_squared_error: 0.8676 - val_y2_output_root_mean_squared_error: 1.3837
# Epoch 101/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.7615 - y1_output_loss: 0.6793 - y2_output_loss: 2.1173 - y1_output_root_mean_squared_error: 0.8278 - y2_output_root_mean_squared_error: 1.4409 - val_loss: 2.5689 - val_y1_output_loss: 0.7614 - val_y2_output_loss: 1.8461 - val_y1_output_root_mean_squared_error: 0.8542 - val_y2_output_root_mean_squared_error: 1.3562
# Epoch 102/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3574 - y1_output_loss: 0.5822 - y2_output_loss: 1.7580 - y1_output_root_mean_squared_error: 0.7664 - y2_output_root_mean_squared_error: 1.3304 - val_loss: 2.7240 - val_y1_output_loss: 0.9436 - val_y2_output_loss: 1.8017 - val_y1_output_root_mean_squared_error: 0.9717 - val_y2_output_root_mean_squared_error: 1.3341
# Epoch 103/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5107 - y1_output_loss: 0.7658 - y2_output_loss: 2.7851 - y1_output_root_mean_squared_error: 0.8726 - y2_output_root_mean_squared_error: 1.6581 - val_loss: 4.7838 - val_y1_output_loss: 0.8454 - val_y2_output_loss: 3.9418 - val_y1_output_root_mean_squared_error: 0.9214 - val_y2_output_root_mean_squared_error: 1.9836
# Epoch 104/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.2951 - y1_output_loss: 0.4931 - y2_output_loss: 1.8304 - y1_output_root_mean_squared_error: 0.6926 - y2_output_root_mean_squared_error: 1.3473 - val_loss: 6.5170 - val_y1_output_loss: 2.4486 - val_y2_output_loss: 3.9989 - val_y1_output_root_mean_squared_error: 1.5776 - val_y2_output_root_mean_squared_error: 2.0071
# Epoch 105/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9174 - y1_output_loss: 0.6866 - y2_output_loss: 2.2484 - y1_output_root_mean_squared_error: 0.8288 - y2_output_root_mean_squared_error: 1.4935 - val_loss: 3.4443 - val_y1_output_loss: 1.2840 - val_y2_output_loss: 2.1477 - val_y1_output_root_mean_squared_error: 1.1317 - val_y2_output_root_mean_squared_error: 1.4709
# Epoch 106/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.6984 - y1_output_loss: 0.6352 - y2_output_loss: 2.0679 - y1_output_root_mean_squared_error: 0.7943 - y2_output_root_mean_squared_error: 1.4379 - val_loss: 4.0538 - val_y1_output_loss: 0.7660 - val_y2_output_loss: 3.3072 - val_y1_output_root_mean_squared_error: 0.8592 - val_y2_output_root_mean_squared_error: 1.8208
# Epoch 107/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.8544 - y1_output_loss: 0.5904 - y2_output_loss: 2.2779 - y1_output_root_mean_squared_error: 0.7667 - y2_output_root_mean_squared_error: 1.5055 - val_loss: 5.1370 - val_y1_output_loss: 0.7276 - val_y2_output_loss: 4.4539 - val_y1_output_root_mean_squared_error: 0.8541 - val_y2_output_root_mean_squared_error: 2.0994
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.7536 - y1_output_loss: 0.8480 - y2_output_loss: 2.9720 - y1_output_root_mean_squared_error: 0.9119 - y2_output_root_mean_squared_error: 1.7094 - val_loss: 38.4345 - val_y1_output_loss: 8.1554 - val_y2_output_loss: 29.6312 - val_y1_output_root_mean_squared_error: 2.8916 - val_y2_output_root_mean_squared_error: 5.4839
# Epoch 109/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.0563 - y1_output_loss: 1.8822 - y2_output_loss: 5.1208 - y1_output_root_mean_squared_error: 1.3771 - y2_output_root_mean_squared_error: 2.2715 - val_loss: 2.3059 - val_y1_output_loss: 0.6900 - val_y2_output_loss: 1.6406 - val_y1_output_root_mean_squared_error: 0.8290 - val_y2_output_root_mean_squared_error: 1.2723
# Epoch 110/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6422 - y1_output_loss: 0.6281 - y2_output_loss: 2.0073 - y1_output_root_mean_squared_error: 0.7910 - y2_output_root_mean_squared_error: 1.4200 - val_loss: 5.5670 - val_y1_output_loss: 1.3626 - val_y2_output_loss: 4.1764 - val_y1_output_root_mean_squared_error: 1.1654 - val_y2_output_root_mean_squared_error: 2.0515
# Epoch 111/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.5927 - y1_output_loss: 0.6041 - y2_output_loss: 1.9650 - y1_output_root_mean_squared_error: 0.7807 - y2_output_root_mean_squared_error: 1.4083 - val_loss: 2.3263 - val_y1_output_loss: 0.5265 - val_y2_output_loss: 1.8306 - val_y1_output_root_mean_squared_error: 0.7250 - val_y2_output_root_mean_squared_error: 1.3419
# Epoch 112/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.8437 - y1_output_loss: 0.5562 - y2_output_loss: 2.3212 - y1_output_root_mean_squared_error: 0.7485 - y2_output_root_mean_squared_error: 1.5111 - val_loss: 8.9790 - val_y1_output_loss: 1.1094 - val_y2_output_loss: 7.8071 - val_y1_output_root_mean_squared_error: 1.0668 - val_y2_output_root_mean_squared_error: 2.8002
# Epoch 113/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2993 - y1_output_loss: 0.7352 - y2_output_loss: 2.5647 - y1_output_root_mean_squared_error: 0.8604 - y2_output_root_mean_squared_error: 1.5997 - val_loss: 3.1022 - val_y1_output_loss: 0.5447 - val_y2_output_loss: 2.5707 - val_y1_output_root_mean_squared_error: 0.7350 - val_y2_output_root_mean_squared_error: 1.6006
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7032 - y1_output_loss: 0.6920 - y2_output_loss: 2.0052 - y1_output_root_mean_squared_error: 0.8276 - y2_output_root_mean_squared_error: 1.4207 - val_loss: 2.7412 - val_y1_output_loss: 0.5455 - val_y2_output_loss: 2.2130 - val_y1_output_root_mean_squared_error: 0.7327 - val_y2_output_root_mean_squared_error: 1.4847
# Epoch 115/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7156 - y1_output_loss: 0.5616 - y2_output_loss: 2.1383 - y1_output_root_mean_squared_error: 0.7520 - y2_output_root_mean_squared_error: 1.4663 - val_loss: 3.2069 - val_y1_output_loss: 0.5371 - val_y2_output_loss: 2.6854 - val_y1_output_root_mean_squared_error: 0.7260 - val_y2_output_root_mean_squared_error: 1.6370
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8867 - y1_output_loss: 1.3452 - y2_output_loss: 3.5844 - y1_output_root_mean_squared_error: 1.1609 - y2_output_root_mean_squared_error: 1.8812 - val_loss: 7.4902 - val_y1_output_loss: 2.2374 - val_y2_output_loss: 5.2052 - val_y1_output_root_mean_squared_error: 1.5050 - val_y2_output_root_mean_squared_error: 2.2858
# Epoch 117/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4327 - y1_output_loss: 0.5918 - y2_output_loss: 1.8559 - y1_output_root_mean_squared_error: 0.7693 - y2_output_root_mean_squared_error: 1.3568 - val_loss: 3.8508 - val_y1_output_loss: 0.8171 - val_y2_output_loss: 3.0583 - val_y1_output_root_mean_squared_error: 0.8911 - val_y2_output_root_mean_squared_error: 1.7484
# Epoch 118/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5949 - y1_output_loss: 0.6240 - y2_output_loss: 1.9782 - y1_output_root_mean_squared_error: 0.7829 - y2_output_root_mean_squared_error: 1.4078 - val_loss: 2.9615 - val_y1_output_loss: 0.8873 - val_y2_output_loss: 2.0615 - val_y1_output_root_mean_squared_error: 0.9440 - val_y2_output_root_mean_squared_error: 1.4389
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4148 - y1_output_loss: 0.5497 - y2_output_loss: 1.8527 - y1_output_root_mean_squared_error: 0.7436 - y2_output_root_mean_squared_error: 1.3645 - val_loss: 2.4139 - val_y1_output_loss: 0.5328 - val_y2_output_loss: 1.9175 - val_y1_output_root_mean_squared_error: 0.7129 - val_y2_output_root_mean_squared_error: 1.3805
# Epoch 120/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.1485 - y1_output_loss: 0.4616 - y2_output_loss: 1.7415 - y1_output_root_mean_squared_error: 0.6760 - y2_output_root_mean_squared_error: 1.3006 - val_loss: 10.4283 - val_y1_output_loss: 1.9927 - val_y2_output_loss: 8.4902 - val_y1_output_root_mean_squared_error: 1.4117 - val_y2_output_root_mean_squared_error: 2.9044
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3475 - y1_output_loss: 0.1276 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.4680 - val_loss: 0.7218 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.5291 - val_y1_output_root_mean_squared_error: 0.4420 - val_y2_output_root_mean_squared_error: 0.7256
# Epoch 462/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3959 - y1_output_loss: 0.1478 - y2_output_loss: 0.2522 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.5031 - val_loss: 1.3076 - val_y1_output_loss: 0.3583 - val_y2_output_loss: 0.9421 - val_y1_output_root_mean_squared_error: 0.6067 - val_y2_output_root_mean_squared_error: 0.9693
# Epoch 463/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3627 - y1_output_loss: 0.1339 - y2_output_loss: 0.2290 - y1_output_root_mean_squared_error: 0.3658 - y2_output_root_mean_squared_error: 0.4784 - val_loss: 0.7673 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.5955 - val_y1_output_root_mean_squared_error: 0.4283 - val_y2_output_root_mean_squared_error: 0.7641
# Epoch 464/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4290 - y1_output_loss: 0.1256 - y2_output_loss: 0.3050 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5511 - val_loss: 0.9751 - val_y1_output_loss: 0.3010 - val_y2_output_loss: 0.6689 - val_y1_output_root_mean_squared_error: 0.5541 - val_y2_output_root_mean_squared_error: 0.8174
# Epoch 465/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2593 - y1_output_loss: 0.1176 - y2_output_loss: 0.1438 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.3767 - val_loss: 1.5467 - val_y1_output_loss: 0.3407 - val_y2_output_loss: 1.2095 - val_y1_output_root_mean_squared_error: 0.5915 - val_y2_output_root_mean_squared_error: 1.0940
# Epoch 466/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4725 - y1_output_loss: 0.1309 - y2_output_loss: 0.3381 - y1_output_root_mean_squared_error: 0.3627 - y2_output_root_mean_squared_error: 0.5840 - val_loss: 0.7084 - val_y1_output_loss: 0.1756 - val_y2_output_loss: 0.5289 - val_y1_output_root_mean_squared_error: 0.4244 - val_y2_output_root_mean_squared_error: 0.7268
# Epoch 467/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3607 - y1_output_loss: 0.1310 - y2_output_loss: 0.2303 - y1_output_root_mean_squared_error: 0.3610 - y2_output_root_mean_squared_error: 0.4800 - val_loss: 0.7258 - val_y1_output_loss: 0.2362 - val_y2_output_loss: 0.4730 - val_y1_output_root_mean_squared_error: 0.4909 - val_y2_output_root_mean_squared_error: 0.6963
# Epoch 468/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4590 - y1_output_loss: 0.1476 - y2_output_loss: 0.3074 - y1_output_root_mean_squared_error: 0.3857 - y2_output_root_mean_squared_error: 0.5571 - val_loss: 0.8201 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.6128 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.7822
# Epoch 469/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4242 - y1_output_loss: 0.1308 - y2_output_loss: 0.2939 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 0.9793 - val_y1_output_loss: 0.2152 - val_y2_output_loss: 0.7451 - val_y1_output_root_mean_squared_error: 0.4710 - val_y2_output_root_mean_squared_error: 0.8703
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3120 - y1_output_loss: 0.1239 - y2_output_loss: 0.1866 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.4337 - val_loss: 0.7068 - val_y1_output_loss: 0.2101 - val_y2_output_loss: 0.4882 - val_y1_output_root_mean_squared_error: 0.4663 - val_y2_output_root_mean_squared_error: 0.6995
# Epoch 471/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3661 - y1_output_loss: 0.1282 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3595 - y2_output_root_mean_squared_error: 0.4867 - val_loss: 0.7585 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.5495 - val_y1_output_root_mean_squared_error: 0.4508 - val_y2_output_root_mean_squared_error: 0.7452
# Epoch 472/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3155 - y1_output_loss: 0.1193 - y2_output_loss: 0.1971 - y1_output_root_mean_squared_error: 0.3461 - y2_output_root_mean_squared_error: 0.4424 - val_loss: 1.2609 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 1.0266 - val_y1_output_root_mean_squared_error: 0.4830 - val_y2_output_root_mean_squared_error: 1.0137
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3200 - y1_output_loss: 0.1265 - y2_output_loss: 0.1910 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.4389 - val_loss: 0.6847 - val_y1_output_loss: 0.1815 - val_y2_output_loss: 0.4973 - val_y1_output_root_mean_squared_error: 0.4311 - val_y2_output_root_mean_squared_error: 0.7063
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4021 - y1_output_loss: 0.1301 - y2_output_loss: 0.2720 - y1_output_root_mean_squared_error: 0.3619 - y2_output_root_mean_squared_error: 0.5207 - val_loss: 1.0410 - val_y1_output_loss: 0.2128 - val_y2_output_loss: 0.8199 - val_y1_output_root_mean_squared_error: 0.4637 - val_y2_output_root_mean_squared_error: 0.9089
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5235 - y1_output_loss: 0.1548 - y2_output_loss: 0.3653 - y1_output_root_mean_squared_error: 0.3945 - y2_output_root_mean_squared_error: 0.6065 - val_loss: 0.6767 - val_y1_output_loss: 0.1728 - val_y2_output_loss: 0.4989 - val_y1_output_root_mean_squared_error: 0.4173 - val_y2_output_root_mean_squared_error: 0.7089
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3635 - y1_output_loss: 0.1226 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.4916 - val_loss: 0.7002 - val_y1_output_loss: 0.2030 - val_y2_output_loss: 0.4882 - val_y1_output_root_mean_squared_error: 0.4530 - val_y2_output_root_mean_squared_error: 0.7036
# Epoch 477/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3453 - y1_output_loss: 0.1202 - y2_output_loss: 0.2317 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.4763 - val_loss: 0.9774 - val_y1_output_loss: 0.3199 - val_y2_output_loss: 0.6453 - val_y1_output_root_mean_squared_error: 0.5729 - val_y2_output_root_mean_squared_error: 0.8057
# Epoch 478/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2737 - y1_output_loss: 0.1193 - y2_output_loss: 0.1567 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.3958 - val_loss: 1.9477 - val_y1_output_loss: 0.6679 - val_y2_output_loss: 1.2537 - val_y1_output_root_mean_squared_error: 0.8264 - val_y2_output_root_mean_squared_error: 1.1246
# Epoch 479/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.6381 - y1_output_loss: 0.1724 - y2_output_loss: 0.4604 - y1_output_root_mean_squared_error: 0.4164 - y2_output_root_mean_squared_error: 0.6817 - val_loss: 0.7387 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.5563 - val_y1_output_root_mean_squared_error: 0.4320 - val_y2_output_root_mean_squared_error: 0.7430
# Epoch 480/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2694 - y1_output_loss: 0.1075 - y2_output_loss: 0.1600 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.4012 - val_loss: 0.7153 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.5173 - val_y1_output_root_mean_squared_error: 0.4462 - val_y2_output_root_mean_squared_error: 0.7184
# Epoch 481/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3711 - y1_output_loss: 0.1269 - y2_output_loss: 0.2425 - y1_output_root_mean_squared_error: 0.3572 - y2_output_root_mean_squared_error: 0.4934 - val_loss: 0.8465 - val_y1_output_loss: 0.3104 - val_y2_output_loss: 0.5353 - val_y1_output_root_mean_squared_error: 0.5590 - val_y2_output_root_mean_squared_error: 0.7307
# Epoch 482/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3299 - y1_output_loss: 0.1142 - y2_output_loss: 0.2149 - y1_output_root_mean_squared_error: 0.3391 - y2_output_root_mean_squared_error: 0.4636 - val_loss: 0.8222 - val_y1_output_loss: 0.1919 - val_y2_output_loss: 0.6229 - val_y1_output_root_mean_squared_error: 0.4432 - val_y2_output_root_mean_squared_error: 0.7911
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4092 - y1_output_loss: 0.1462 - y2_output_loss: 0.2634 - y1_output_root_mean_squared_error: 0.3828 - y2_output_root_mean_squared_error: 0.5125 - val_loss: 1.2398 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.9727 - val_y1_output_root_mean_squared_error: 0.5173 - val_y2_output_root_mean_squared_error: 0.9860
# Epoch 484/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3796 - y1_output_loss: 0.1358 - y2_output_loss: 0.2406 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.4925 - val_loss: 0.7556 - val_y1_output_loss: 0.1855 - val_y2_output_loss: 0.5594 - val_y1_output_root_mean_squared_error: 0.4370 - val_y2_output_root_mean_squared_error: 0.7514
# Epoch 485/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2599 - y1_output_loss: 0.1153 - y2_output_loss: 0.1540 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.3850 - val_loss: 1.0284 - val_y1_output_loss: 0.2592 - val_y2_output_loss: 0.7826 - val_y1_output_root_mean_squared_error: 0.5077 - val_y2_output_root_mean_squared_error: 0.8779
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3090 - y1_output_loss: 0.1152 - y2_output_loss: 0.1949 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.4394 - val_loss: 0.6838 - val_y1_output_loss: 0.1601 - val_y2_output_loss: 0.5314 - val_y1_output_root_mean_squared_error: 0.4048 - val_y2_output_root_mean_squared_error: 0.7210
# Epoch 487/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4678 - y1_output_loss: 0.1357 - y2_output_loss: 0.3293 - y1_output_root_mean_squared_error: 0.3702 - y2_output_root_mean_squared_error: 0.5751 - val_loss: 0.8595 - val_y1_output_loss: 0.2045 - val_y2_output_loss: 0.6532 - val_y1_output_root_mean_squared_error: 0.4574 - val_y2_output_root_mean_squared_error: 0.8064
# Epoch 488/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3626 - y1_output_loss: 0.1259 - y2_output_loss: 0.2379 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 1.1621 - val_y1_output_loss: 0.2746 - val_y2_output_loss: 0.8903 - val_y1_output_root_mean_squared_error: 0.5293 - val_y2_output_root_mean_squared_error: 0.9391
# Epoch 489/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3762 - y1_output_loss: 0.1337 - y2_output_loss: 0.2404 - y1_output_root_mean_squared_error: 0.3662 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 0.7307 - val_y1_output_loss: 0.1719 - val_y2_output_loss: 0.5480 - val_y1_output_root_mean_squared_error: 0.4201 - val_y2_output_root_mean_squared_error: 0.7444
# Epoch 490/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3295 - y1_output_loss: 0.1180 - y2_output_loss: 0.2127 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.4606 - val_loss: 1.1647 - val_y1_output_loss: 0.3036 - val_y2_output_loss: 0.8529 - val_y1_output_root_mean_squared_error: 0.5589 - val_y2_output_root_mean_squared_error: 0.9232
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3054 - y1_output_loss: 0.1298 - y2_output_loss: 0.1766 - y1_output_root_mean_squared_error: 0.3601 - y2_output_root_mean_squared_error: 0.4192 - val_loss: 0.7927 - val_y1_output_loss: 0.1778 - val_y2_output_loss: 0.6156 - val_y1_output_root_mean_squared_error: 0.4254 - val_y2_output_root_mean_squared_error: 0.7822
# Epoch 492/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3075 - y1_output_loss: 0.1196 - y2_output_loss: 0.1927 - y1_output_root_mean_squared_error: 0.3441 - y2_output_root_mean_squared_error: 0.4349 - val_loss: 1.1433 - val_y1_output_loss: 0.2707 - val_y2_output_loss: 0.8634 - val_y1_output_root_mean_squared_error: 0.5211 - val_y2_output_root_mean_squared_error: 0.9337
# Epoch 493/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2616 - y1_output_loss: 0.1146 - y2_output_loss: 0.1495 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.3864 - val_loss: 1.3753 - val_y1_output_loss: 0.3916 - val_y2_output_loss: 0.9665 - val_y1_output_root_mean_squared_error: 0.6341 - val_y2_output_root_mean_squared_error: 0.9865
# Epoch 494/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3457 - y1_output_loss: 0.1242 - y2_output_loss: 0.2207 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.4709 - val_loss: 0.7510 - val_y1_output_loss: 0.2443 - val_y2_output_loss: 0.4898 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.7071
# Epoch 495/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3468 - y1_output_loss: 0.1232 - y2_output_loss: 0.2222 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.4727 - val_loss: 0.6209 - val_y1_output_loss: 0.1741 - val_y2_output_loss: 0.4457 - val_y1_output_root_mean_squared_error: 0.4215 - val_y2_output_root_mean_squared_error: 0.6658
# Epoch 496/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3246 - y1_output_loss: 0.1256 - y2_output_loss: 0.1999 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.4457 - val_loss: 1.1990 - val_y1_output_loss: 0.2656 - val_y2_output_loss: 0.9372 - val_y1_output_root_mean_squared_error: 0.5192 - val_y2_output_root_mean_squared_error: 0.9641
# Epoch 497/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4229 - y1_output_loss: 0.1464 - y2_output_loss: 0.2745 - y1_output_root_mean_squared_error: 0.3840 - y2_output_root_mean_squared_error: 0.5248 - val_loss: 0.8773 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.6582 - val_y1_output_root_mean_squared_error: 0.4665 - val_y2_output_root_mean_squared_error: 0.8122
# Epoch 498/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4565 - y1_output_loss: 0.1470 - y2_output_loss: 0.3068 - y1_output_root_mean_squared_error: 0.3837 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 0.6772 - val_y1_output_loss: 0.1935 - val_y2_output_loss: 0.4762 - val_y1_output_root_mean_squared_error: 0.4415 - val_y2_output_root_mean_squared_error: 0.6945
# Epoch 499/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2954 - y1_output_loss: 0.1143 - y2_output_loss: 0.1827 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4259 - val_loss: 0.7191 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.5305 - val_y1_output_root_mean_squared_error: 0.4381 - val_y2_output_root_mean_squared_error: 0.7261
# Epoch 500/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3273 - y1_output_loss: 0.1253 - y2_output_loss: 0.2053 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.4487 - val_loss: 0.9677 - val_y1_output_loss: 0.1838 - val_y2_output_loss: 0.7960 - val_y1_output_root_mean_squared_error: 0.4253 - val_y2_output_root_mean_squared_error: 0.8870

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.9677 - y1_output_loss: 0.1802 - y2_output_loss: 0.7880 - y1_output_root_mean_squared_error: 0.4253 - y2_output_root_mean_squared_error: 0.8870
# Loss = 0.9677370059025752, Y1_loss = 0.18020911514759064, Y1_mse = 0.42534881830215454, Y2_loss = 0.7879770398139954, Y2_mse = 0.8870261311531067

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
